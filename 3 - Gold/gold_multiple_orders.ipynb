# %%
# %run ../_utils
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: unidecode in /local_disk0/.ephemeral_nfs/envs/pythonEnv-83bcf99d-0e56-4ba3-8e8d-2470fdf01d30/lib/python3.10/site-packages (1.3.8)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
from pyspark.sql.functions import col, count, when

# %% [markdown]
# # Camada GOLD
#
# Na camada gold, as limpezas e ajustes já foram feitos, então essa camada é responsável por aplicar regras de negócio, agregações e junções de dados que convirjam para analises.
#
# Essa é uma tabela sumarizada analítica.
#
# O objetivo dela é informar os meses em que tiveram mais pedidos

# %%
tb_name = "olist_gold.multiple_orders"
dataset_location = "olist_multiple_orders_dataset"
target_location = f"dbfs:/FileStore/delta/brazilian_ecommerce/{dataset_location}/gold"

# %% [markdown]
# ## 1 - Data ingestion

# %%
df = spark.read.table("olist_gold.customer_orders") # leituira da delta table central, orders (ja da propria gold)

# %% [markdown]
# ## 2 - preparation

# %%
df = df.groupBy("customer_unique_id").agg(
    count("order_id").alias("total_orders"),
)

# %% [markdown]
# # 2.1 multiple_orders?
#
# informar se o cliente comprou mais de uma vez

# %%
df = df.withColumn("multiple_order", when(col("total_orders") > 1, True).otherwise(False))

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_unique_id</th><th>total_orders</th><th>multiple_order</th></tr></thead><tbody><tr><td>969cdc8af5b07074766e79c1e6d76c24</td><td>1</td><td>false</td></tr><tr><td>f2a9bc9a1db05c873e1419654f747f9e</td><td>1</td><td>false</td></tr><tr><td>d0c5e56e04e886e73c79b3b71f0d6f0b</td><td>1</td><td>false</td></tr><tr><td>5f03b965e26e79a371d229cfeeb578d7</td><td>1</td><td>false</td></tr><tr><td>14a188558af6cd5bc222ca773d395a7f</td><td>2</td><td>true</td></tr><tr><td>ef1c2fafea5285a4bfb61386bc5e3154</td><td>1</td><td>false</td></tr><tr><td>d339ed835c9d8fd6b1e3c5cb60850bc5</td><td>1</td><td>false</td></tr><tr><td>39d6e50625a51a618c2cf02a026231c1</td><td>1</td><td>false</td></tr><tr><td>8d2fa65d968da66afc05f2e28250c9dc</td><td>1</td><td>false</td></tr><tr><td>d04921557f1cde4963c30a11dfb1719d</td><td>1</td><td>false</td></tr><tr><td>8033f408bcb75134075db3eb60b49937</td><td>1</td><td>false</td></tr><tr><td>9ea65227cfac84dd2778bc0315dd8f10</td><td>1</td><td>false</td></tr><tr><td>2a6ef69674d6f28002c72b8d123b3a27</td><td>1</td><td>false</td></tr><tr><td>308dfe5168e217902973b27e7c91f27e</td><td>1</td><td>false</td></tr><tr><td>1d2435aa3b858d45c707c9fc25e18779</td><td>3</td><td>true</td></tr><tr><td>538f20c5da86daf31ec285792b8b603f</td><td>1</td><td>false</td></tr><tr><td>968436577c1e2073b28031261cb45a24</td><td>1</td><td>false</td></tr><tr><td>1843cceebcc1e391249a2714facc8ba3</td><td>1</td><td>false</td></tr><tr><td>86669cc06c6e824b3f2edfc2daef762e</td><td>1</td><td>false</td></tr><tr><td>c114c44566c2d172b520bc3c8785ffdf</td><td>1</td><td>false</td></tr><tr><td>f13f6afa0bcce14330a5bcb6f1076904</td><td>1</td><td>false</td></tr><tr><td>8c2c7fb3be4fc1669b8c1c6059db1207</td><td>1</td><td>false</td></tr><tr><td>384ffc528dd30fd49eff3dda9f00ce86</td><td>1</td><td>false</td></tr><tr><td>10aa79627a28350b5c121a124096cb18</td><td>1</td><td>false</td></tr><tr><td>19fe66d478bfedfdcc743014d562b777</td><td>1</td><td>false</td></tr><tr><td>09976ab240099cc26220384fa752e4f1</td><td>1</td><td>false</td></tr><tr><td>e2fa02776abcbf7246ffd18f58e120ea</td><td>1</td><td>false</td></tr><tr><td>dfe634d4b8e0678799178b6ec8e1b0ba</td><td>1</td><td>false</td></tr><tr><td>61bf8e4656ece5791021786c756f1894</td><td>1</td><td>false</td></tr><tr><td>65be6248a39942f9ab10da91280e2576</td><td>1</td><td>false</td></tr><tr><td>7d27012b117e625faff580bec7cdf2e1</td><td>1</td><td>false</td></tr><tr><td>d242c2a33b19c5fab2ccf4f67dcaba86</td><td>1</td><td>false</td></tr><tr><td>f43b5eb3178b2129b9c4ea51024fcbd9</td><td>1</td><td>false</td></tr><tr><td>39735e754fd0147ac6b0b910b710e6de</td><td>1</td><td>false</td></tr><tr><td>aadd69366d3b2ff8d40da4f079a4fcf7</td><td>1</td><td>false</td></tr><tr><td>90c329efbf418634b40f4a2a75d9331e</td><td>1</td><td>false</td></tr><tr><td>f1eb09d2858a28f796484f8a9dfe2872</td><td>1</td><td>false</td></tr><tr><td>04ebe7670da121a91344d0fd5547222f</td><td>1</td><td>false</td></tr><tr><td>dddcc50cec9aabfe44b26c136236db0a</td><td>1</td><td>false</td></tr><tr><td>8b6afb5c9eb182373c656b34bf3383fc</td><td>1</td><td>false</td></tr><tr><td>3195d6c23c9f61b0bcfae41d3fe8a3db</td><td>1</td><td>false</td></tr><tr><td>9eedcaf541a8a393248b2017afecf694</td><td>1</td><td>false</td></tr><tr><td>8e61d2d055f4865036e7d62b6739c255</td><td>1</td><td>false</td></tr><tr><td>30cd4e5146e6f7b12f08bacaec791418</td><td>1</td><td>false</td></tr><tr><td>02bab436d042d111ec4b7c67cfab8835</td><td>1</td><td>false</td></tr><tr><td>1973beff39565594011f9a0ef66f923e</td><td>1</td><td>false</td></tr><tr><td>1a6c2d0ed3299790cb718bb7981558c7</td><td>1</td><td>false</td></tr><tr><td>1234ccd4e0b359525af98b7d68ea4a7a</td><td>1</td><td>false</td></tr><tr><td>5f25063bd0fd1006d687a2565ec6964a</td><td>1</td><td>false</td></tr><tr><td>a7065fb28bf540beba112541b69f7925</td><td>1</td><td>false</td></tr><tr><td>361cfdd28b129a0d3ff26731e96e4e53</td><td>1</td><td>false</td></tr><tr><td>36516895f52da0 ...

# %% [markdown]
# ## Saving data

# %%
save_dataframe(df, format_mode="delta", table_name=tb_name, target_location=target_location)
# Out:
# [LOG] Saving olist_gold.multiple_orders delta on dbfs:/FileStore/delta/brazilian_ecommerce/olist_multiple_orders_dataset/gold... OK!

# %% [markdown]
# ## create delta table
#
# TODO: implementar UPSERT
#
# o upsert serve para não precisar reescrever todos os dados, mas aproveitar do Delta para fazer um MERGE, caso um registro antigo tenha uma nova versão e INSERT para os dados que são novos

# %%
create_table(table_name=tb_name, target_location=target_location)
# Out:
# [LOG] Creating delta table olist_gold.multiple_orders on dbfs:/FileStore/delta/brazilian_ecommerce/olist_multiple_orders_dataset/gold... OK!

# %%
# exit para fechar a execução
dbutils.notebook.exit("OK")

# %%
# %sql

select * from olist_gold.multiple_orders
